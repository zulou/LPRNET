# %%
import argparse 
from time import time 

import numpy as np 
import cv2 
import os 
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf 

from model import LPRNet 
from tensorflow.keras.models import load_model
os.environ['CUDA_DIR'] = '/usr/lib/cuda'
os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/usr/lib/cuda'
# Out:
# 2025-01-23 16:21:03.212152: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737667263.223593   30575 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737667263.227065   30575 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-23 16:21:03.239841: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from time import time
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

def run():
    # Load the Keras model
    model = load_model("./saved_models/500_epochs_new_out_model_last.h5")
    print("Loaded Weights successfully")
    print("Actual Label \t Predicted Label")
    start_time = time()
    cnt = 0

    # Loop through all the files in the test folder
    for filename in os.listdir("./valid/"):
        # Check if the file is an image
        if filename.endswith(".jpg") or filename.endswith(".JPG"):
            # Read the file and preprocess it
            frame = cv2.imread(f"./valid/{filename}")
            img = cv2.resize(frame, (94, 24))
            img = np.expand_dims(img, axis=0)

            # Get the output sequence
            pred = model.predict(img)

            # Decode the output sequence using Keras CTC decode
            result_ctc = decode_pred(pred, classnames)
            original_label = filename.split("_")[0]

            # Print the original sequence and the decoded sequence
            print(original_label, "\t", result_ctc[0].decode('utf-8'))

            # Visualize the image, actual label, and predicted label
            plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
            plt.title(f"Actual: {original_label}\nPredicted: {result_ctc[0].decode('utf-8')}")
            plt.axis('off')  # Hide axes
            plt.show()

            cnt += 1

    print("Total time taken:", time() - start_time)

def decode_pred(pred, classnames):
    pred = np.mean(pred, axis=1)
    samples, times = pred.shape[:2]
    input_length = tf.convert_to_tensor([times] * samples)
    decodeds, logprobs = tf.keras.backend.ctc_decode(pred, input_length, greedy=True, beam_width=100, top_paths=1)
    decodeds = np.array(decodeds[0])

    results = []
    for d in decodeds:
        text = []
        for idx in d:
            if idx == -1:
                break
            text.append(classnames[idx])
        results.append(''.join(text).encode('utf-8'))
    return results

if __name__ == "__main__":
    classnames = "ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789"
    IMG_SIZE = [94, 24]
    run()
# Out:
# Starting program...
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Loaded Weights successfully
# Actual Label 	 Predicted Label
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step
# WC5070 	 WC5D70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# WC5070 	 WC5D70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# PFZH84 	 PFZH84
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PHJY50 	 PHJY50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# WD4111 	 WD4111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# PFYH44 	 0PFYH44
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XB5658 	 XB5658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XA9930 	 XR9930
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PGSV23 	 PGSV23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TP2504 	 TP2504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# WD4111 	 WD4111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# VX6680 	 X6680
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# WK7747 	 WK7747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ZN4221 	 Z4221
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PHJY50 	 PHJY50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PGKY76 	 PGKY76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TW7558 	 TW7558
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PFBG13 	 PFBG13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PDZH76 	 PDZH76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# PFYH22 	 PFYH22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# WK7747 	 WK7747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# WK7747 	 WK7747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PGKY76 	 PGKY76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XB5658 	 XB5658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PFYH22 	 PFYH22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XU6908 	 XD69D08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TP2504 	 TP25D04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PFYH44 	 PFYH44
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# WD4111 	 WD41T11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# PDZH76 	 PDZH76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# XU6908 	 XD6908
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TP2504 	 TP25D04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XU6908 	 XD69D08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# VX6680 	 VX8680
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PHJY50 	 PHJY50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XU6908 	 XD6908
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ZN4221 	 Z4221
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# XV2499 	 XV2499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TP2504 	 TP25D04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ZN4221 	 Z4221
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# WD4111 	 WD4111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# WK7747 	 WK7747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# WD4111 	 WD4111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# PHJY50 	 PHJY50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# PFYH44 	 PFYH44
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# XB5658 	 XB5658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# YY7806 	 YY78D6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# PFBG13 	 PFBG13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# PFYH22 	 PFYH22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# ZB5973 	 ZB5973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# PGKY76 	 PGKY76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# PFYH22 	 PFYH22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# WK7747 	 WK7747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# WC5070 	 WC5D70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# PFYH22 	 PFYH22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# PFYH22 	 PFYH22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# WC5070 	 WC5D70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# WK7747 	 WK7747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# PHJY50 	 PHJY50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# PFZH84 	 PFZH84
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# WK7747 	 WK7747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# TW7558 	 TW7558
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# PFYH44 	 PFYH441
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# XV2499 	 XV2499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PDZH76 	 PDZH76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# TP2504 	 TP25D4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# ZB5973 	 ZB5973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PGSV23 	 PGSV23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# ZB5973 	 ZB5973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PGSV23 	 PGSV23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PGSV23 	 PGSV23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XW7088 	 XW7D88
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XW7088 	 XW7D88
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PFYH44 	 PFYH44
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XU6908 	 XD6908
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PGKY76 	 PGKY76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# PFZH84 	 PFZH84
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XV2499 	 XV2499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# PFBG13 	 PFBG13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ZB5973 	 ZB5973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PHJY50 	 PHJY50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# WD4111 	 WD4111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TP2504 	 TP25D4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ZB5973 	 ZB5973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# PFZH84 	 PFZH84
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PFYH44 	 PFYH44
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PFZH84 	 PFZH84
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PFYH22 	 PFYH22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TP2504 	 TP25D04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PFBG13 	 PFBG13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PFYH22 	 PFYH22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# WK7747 	 WK7747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# YY7806 	 YY78D6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# YY7806 	 YY78D06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TW7558 	 TW7558
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# PHJY50 	 PHJY50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TP2504 	 TP25D04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PDZH76 	 DZH76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PFBG13 	 PFBG13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XB5658 	 XB5658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PHJY50 	 PHJY50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XB5658 	 XB5658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# PHJY50 	 PHJY50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ZB5973 	 ZB5973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PHJY50 	 PHJY50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TP2504 	 TP25D04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# PFBG13 	 PFBG13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TW7558 	 TW7558
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# XV2499 	 XV2499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# XU6908 	 XD69D08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# WD4111 	 WD4111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TP2504 	 TP2504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# PFZH84 	 RFZH4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# SL3405 	 SL34D5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ZL3717 	 ZL3717
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# TP2504 	 TP25D04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# WC5070 	 WC5D70
# Total time taken: 9.665817737579346
